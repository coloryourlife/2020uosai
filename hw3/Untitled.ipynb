# %%
from matplotlib import pyplot as plt
import numpy as np

# %%
m = [0,0,1,1]
n = [0,1,0,1]
x = np.arange(0,2)
y = [-0.58/0.31*b for b in range(0,2)]
a = np.arange(0,2)
b = [-0.81/0.64*b for b in range(0,2)]
plt.plot(x,y)
plt.plot(a,b)
plt.scatter(m,n)
plt.show()

# %%
y = [6.75/6.54*b - 3.27/6.54 for b in range(0,2)]
b = [7.03/7.14*b + 3.76/7.14 for b in range(0,2)]
plt.plot(x,y)
plt.plot(a,b)
plt.scatter(m,n)
plt.show()

# %%
y = [-q + 4.61/3.03 for q in range(0,2)]
b = [-w + 1.9/5.15 for w in range(0,2)]
plt.plot(x,y)
plt.plot(a,b) 
plt.scatter(m,n)
plt.show()
