# %%
m = [0,0,1,1,0.5,1,0,0.5,0.5]
n = [0,1,0,1,1,0.5,0.5,0,0.5]
x = np.arange(0,2)
w1 = 0.28
w2 = 0.7
w3 = 0.28
w4 = 0.48
b1 = 0
b2 = 0
y = [-w1/w2*b - b1/w2 for b in range(0,2)]
a = np.arange(0,2)
b = [-w3/w4*b - b2/w4 for b in range(0,2)]
plt.plot(x,y)
plt.plot(a,b)
plt.scatter(m,n)
plt.show()

# %%
def sigmoid(x):
    return 1 / (1+np.exp(-x))
def forward(w1,w2,bias):
    li = []
    li.append(sigmoid(bias))
    li.append(sigmoid(w2 + bias))
    li.append(sigmoid(w1 + bias))
    li.append(sigmoid(w1 + w2 + bias))
    return li

# %%
from matplotlib import pyplot as plt
import numpy as np

# %%
w5 = 0.2
w6 = 0.52
b3 = 0
y = [w5/w6 * b + b3 for b in range(0,2)]
so = forward(w1,w2,b1)
su = forward(w3,w4,b2)
plt.scatter(so,su)
plt.plot(x,y)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
w1 = -0.46
w2 = -0.79
w3 = -4.18
w4 = -4.25
b1 = -0.73
b2 = 0.47
y = [-w1/w2*b - b1/w2 for b in range(0,2)]
b = [-w3/w4*b - b2/w4 for b in range(0,2)]
plt.plot(x,y)
plt.plot(a,b)
plt.scatter(m,n)
plt.show()

# %%
y = [4.25/1.04 * b + 0.47/1.04 for b in range(0,2)]
so = forward(-4.19,-4.26,0.47)
su = forward(-0.43,-0.88,-0.71)
plt.scatter(so,su)
plt.plot(x,y)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
w1 = -2.85
w2 = -2.84
w3 = -5.44
w4 = -5.53
b1 = 3.98
b2 = 1.66
y = [-w1/w2*b - b1/w2 for b in range(0,2)]
b = [-w3/w4*b - b2/w4 for b in range(0,2)]
plt.plot(x,y)
plt.plot(a,b)
plt.scatter(m,n)
plt.show()

# %%
y = [6.85/6.27 * b + 2.7/6.27for b in range(0,2)]
so = forward(-5.58,-5.69,1.87)
su = forward(-3.21,-3.21,4.6)
plt.scatter(so,su)
plt.plot(x,y)2
plt.show
# Out:
#   File "<ipython-input-84-8b712bab714f>", line 5
#     plt.plot(x,y)2
#                  ^
# SyntaxError: invalid syntax

# %%
w1 = -4.58
w2 = -9.43
w3 = -5.5
w4 = -11.25
b1 = 8.45
b2 = 6.22
y = [-w1/w2*b - b1/w2 for b in range(0,2)]
b = [-w3/w4*b - b2/w4 for b in range(0,2)]
plt.plot(x,y)
plt.plot(a,b)
plt.scatter(m,n)
plt.show()

# %%
# Out:
# [0.5786988226421793, 0.2945243297661403]
